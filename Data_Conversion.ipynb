# %%
import os
import pandas as pd
import numpy as np

# %%
file_path = 'arxiv-metadata-oai-snapshot.json'

print(f'ArXiv Metadata File Size: {os.stat(file_path).st_size / (1024**2)} MB')
records = 0
with open(file_path, 'r', encoding='utf-8') as data_json:
    for record in data_json:
        records += 1
        
print('Number of Records in Data: ', records)
# Out:
# ArXiv Metadata File Size: 2750.555501937866 MB
# Number of Records in Data:  1789907

# %%
#load file into data frame
with open(file_path, 'r', encoding='utf-8') as data_json:
    data = pd.read_json(data_json, lines = True)

# %%
data.head(10)
# Out:
#                                             abstract  \
# 0    A fully differential calculation in perturba...
# 1    We describe a new algorithm, the $(k,\ell)$-...
# 2    The evolution of Earth-Moon system is descri...
# 3    We show that a determinant of Stirling cycle...
# 4    In this paper we show how to compute the $\L...
# 5    We study the two-particle wave function of p...
# 6    A rather non-standard quantum representation...
# 7    A general formulation was developed to repre...
# 8    We discuss the results from the combined IRA...
# 9    Partial cubes are isometric subgraphs of hyp...
#
#                                              authors  \
# 0  C. Bal\'azs, E. L. Berger, P. M. Nadolsky, C.-...
# 1                    Ileana Streinu and Louis Theran
# 2                                        Hongjun Pan
# 3                                       David Callan
# 4           Wael Abu-Shammala and Alberto Torchinsky
# 5                           Y. H. Pong and C. K. Law
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1789907 entries, 0 to 1789906
# Data columns (total 14 columns):
# abstract          object
# authors           object
# authors_parsed    object
# categories        object
# comments          object
# doi               object
# id                object
# journal-ref       object
# license           object
# report-no         object
# submitter         object
# title             object
# update_date       object
# versions          object
# dtypes: object(14)
# memory usage: 191.2+ MB

# %%
data.to_pickle('arxiv_fulldataset.pkl')

# %%
import matplotlib.pyplot as plt
from matplotlib import rcParams
rcParams['text.usetex'] = True

txte = r'$\mathcal{F}$'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-d857e1938976> in <module>()
#       5 txte = r'$\mathcal{F}$'
#       6
# ----> 7 plt.text(txte, fontsize=14)
#       8 plt.show()
#
# TypeError: text() missing 2 required positional arguments: 'y' and 's'
